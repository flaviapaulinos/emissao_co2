# %% [markdown]
# ## Construção do modelo de classificação:
# Implementar um modelo de clustering usando o algoritmo K-Means para segmentar os clientes em grupos homogêneos baseados em suas características demográficas e comportamentais.

# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from imblearn.combine import SMOTETomek

from sklearn.compose import ColumnTransformer
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    LabelEncoder, 
    MinMaxScaler, 
    OrdinalEncoder,
    OneHotEncoder, 
    PowerTransformer,
    StandardScaler,
)

# classificador referência
from sklearn.dummy import DummyClassifier

# estudo lineares
from sklearn.linear_model import LogisticRegression

#estudo knn
from sklearn.neighbors import KNeighborsClassifier

# estudo árvores
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# estudo SVM
from sklearn.svm import SVC

# estudo kNN
from sklearn.neighbors import KNeighborsClassifier

from src.auxiliares import dataframe_coeficientes
from src.config import DADOS_LIMPOS,  MODELO
from src.graficos_s import plot_comparar_metricas_modelos, plot_coeficientes
from src.models_smoteenn import RANDOM_STATE
from src.models_smoteenn import (
    grid_search_cv_classificador,
    treinar_e_validar_modelo_classificacao,
    organiza_resultados,
)


sns.set_theme(palette='viridis')

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#    Idade Attrition          Viagens trab  Sal diário  \
# 0     41       Sim       Viaja_raramente        1102
# 1     49       Não  Viaja_frequentemente         279
# 2     37       Sim       Viaja_raramente        1373
# 3     33       Não  Viaja_frequentemente        1392
# 4     27       Não       Viaja_raramente         591
#
#                  Departamento  Distância casa  Formação acad  \
# 0                      Vendas         1.60934              2
# 1  Pesquisa e Desenvolvimento        12.87472              1
# 2  Pesquisa e Desenvolvimento         3.21868              2
# 3  Pesquisa e Desenvolvimento         4.82802              4
# 4  Pesquisa e Desenvolvimento         3.21868              1
#
#              Área form  Satisf amb     Gênero  ...  Avaliação desemp  \
# 0  Ciências biológicas           2   Feminino  ...                 3
# 1  Ciências biológicas           3  Masculino  ...                 4
# 2               Outros           4  Masculino  ...                 3
# 3  Ciências biológicas           4   Feminino  ...                 3
# 4     Ciências médicas           1  Masculino  ...                 3
#
#    Satisf relac  Opc ações Anos traba  Treinam ultm ano Equil vida-trab  \
# 0             1          0          8                 0               1
# 1             4          1         10                 3               3
# 2             2          0          7                 3               3
# 3             3          0          8                 3               3
# 4             4          1          6                 3               3
#
#    Anos empresa  Anos cargo atual  Anos ult prom Anos gerente atual
# 0             6                 4              0                  5
# 1            10                 7              1                  7
# 2             0                 0              0                  0
# 3             8                 7              3                  0
# 4             2                 2              2                  2
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Idade               1470 non-null   int64
#  1   Attrition           1470 non-null   object
#  2   Viagens trab        1470 non-null   object
#  3   Sal diário          1470 non-null   int64
#  4   Departamento        1470 non-null   object
#  5   Distância casa      1470 non-null   float64
#  6   Formação acad       1470 non-null   int64
#  7   Área form           1470 non-null   object
#  8   Satisf amb          1470 non-null   int64
#  9   Gênero              1470 non-null   object
#  10  Sal hora            1470 non-null   int64
#  11  Envolv trab         1470 non-null   int64
#  12  Nível cargo         1470 non-null   int64
#  13  Cargo               1470 non-null   object
#  14  Satisf trab         1470 non-null   int64
#  15  Estado civil        1470 non-null   object
#  16  Renda mensal        1470 non-null   int64
#  17  Taxa mensal         1470 non-null   int64
#  18  Nº empresas trab    1470 non-null   int64
#  19  Hora extra          1470 non-null   object
#  20  % aumento sal       1470 non-null   int64
#  21  Avaliação desemp    1470 non-null   int64
#  22  Satisf relac        1470 non-null   int64
#  23  Opc ações           1470 non-null   int64
#  24  Anos traba          1470 non-null   int64
#  25  Treinam ultm ano    1470 non-null   int64
#  26  Equil vida-trab     1470 non-null   int64
#  27  Anos empresa        1470 non-null   int64
#  28  Anos cargo atual    1470 non-null   int64
#  29  Anos ult prom       1470 non-null   int64
#  30  Anos gerente atual  1470 non-null   int64
# dtypes: float64(1), int64(22), object(8)
# memory usage: 356.1+ KB

# %%
# Agrupamento das colunas de acordo com o pré-processamento necessário
colunas_categoricas_nao_ordenadas = [
    'Viagens trab',
    'Departamento',
    'Área form',
    'Gênero',
    'Cargo',
    'Estado civil',
    'Hora extra'
]
colunas_categoricas_ordenadas = [
    'Satisf amb',
    'Formação acad',
    'Satisf trab',
    'Envolv trab',
    'Nível cargo',
    'Avaliação desemp',
    'Satisf relac',
    'Opc ações',
    'Equil vida-trab',
     
]
coluna_target= ['Attrition']

colunas_numericas = [coluna for coluna in df.columns if coluna not in (
    colunas_categoricas_nao_ordenadas+colunas_categoricas_ordenadas+coluna_target)
                              ]
colunas_numericas
# Out:
# ['Idade',
#  'Sal diário',
#  'Distância casa',
#  'Sal hora',
#  'Renda mensal',
#  'Taxa mensal',
#  'Nº empresas trab',
#  '% aumento sal',
#  'Anos traba',
#  'Treinam ultm ano',
#  'Anos empresa',
#  'Anos cargo atual',
#  'Anos ult prom',
#  'Anos gerente atual']

# %% [markdown]
# Na EDA foi possível perceber que algumas colunas numéricas tinham uma distribuição bem distinta, que não se aproximava a distribuição normal: 'DailyRate', 'HourlyRate', 'MonthlyRate'. Nesses casos vou usar o MinMaxScaler para trabalhar o escalonamento sem focar na distribuição.
# A coluna Age apresenta uma distribuição próxima do normal, por isso vou usar o StandarScaler e para as demais usarei o PowerTransformer para transformar os valores em uma distribuição mais normal.

# %%
colunas_numericas_min_max = [ coluna for coluna in df.filter(like='Tarifa').columns]
colunas_numericas_min_max

coluna_numerica_std= ['Idade']
colunas_numericas_power_transformer= [coluna for coluna in colunas_numericas if coluna not in (
    coluna_numerica_std +colunas_numericas_min_max)
]
colunas_numericas_power_transformer
# Out:
# ['Sal diário',
#  'Distância casa',
#  'Sal hora',
#  'Renda mensal',
#  'Taxa mensal',
#  'Nº empresas trab',
#  '% aumento sal',
#  'Anos traba',
#  'Treinam ultm ano',
#  'Anos empresa',
#  'Anos cargo atual',
#  'Anos ult prom',
#  'Anos gerente atual']

# %%
X= df.drop(columns=coluna_target)
y= df[coluna_target]

# %%
#codificação da coluna target
le = LabelEncoder()

y = le.fit_transform(y.values.ravel())
y
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# %% [markdown]
# Fluxo da Análise:
# 1. Pré-processamento dos Dados:
# Transformação de Variáveis:
#
# Variáveis categóricas são codificadas via OneHotEncoder
#
# Variáveis numéricas serão escalonadas

# %%
# Preprocessamento
preprocessamento = ColumnTransformer(
    transformers=[
        ('one_hot', OneHotEncoder(drop='first'), colunas_categoricas_nao_ordenadas),
        ('ordinal', OrdinalEncoder(categories='auto'),colunas_categoricas_ordenadas),
        ('min_max', MinMaxScaler(), colunas_numericas_min_max),
        ('standard', StandardScaler(), coluna_numerica_std),
        ('power_transformer', PowerTransformer(), colunas_numericas_power_transformer)
    ]
)

# %%
classificadores = {
    "DummyClassifier": {
        "preprocessor": preprocessamento,
        "classificador": DummyClassifier(strategy="stratified")
    },
    
     "LogisticRegression": {
        "preprocessor": preprocessamento,
        "classificador": LogisticRegression()
    },
     
    "SVC": {
        "preprocessor": preprocessamento,
        "classificador": SVC()
    },

     "KneighborsClassifier":{
        "preprocessor": preprocessamento,
        "classificador": KNeighborsClassifier()
           
    }, 
  
    # modelos baseado em árvores de decisão

      "DecisionTreeClassifier": {
        "preprocessor": preprocessamento,
        "classificador": DecisionTreeClassifier()
    },

    
     "XGBClassifier": {
        "preprocessor": preprocessamento,
        "classificador": XGBClassifier(
            random_state=RANDOM_STATE,
            n_jobs=-1,
        )
     },

    "LGBMClassifier": {
        "preprocessor": preprocessamento,
        "classificador": LGBMClassifier(
            random_state=RANDOM_STATE,
            n_jobs=-1,
            verbose=-1
        )
    }, 
   
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_classificacao(X, y, kf, **classificador)
    for nome_modelo, classificador in classificadores.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                      model  fit_time score_time test_accuracy  \
# 0          DummyClassifier  1.383567   0.054531       0.47619
# 1          DummyClassifier  0.189507   0.063572           0.5
# 2          DummyClassifier  0.196193   0.136619      0.496599
# 3          DummyClassifier   0.20473   0.090739      0.452381
# 4          DummyClassifier   0.17151    0.07758      0.442177
# 5       LogisticRegression  0.298283   0.067616      0.744898
# 6       LogisticRegression  0.288135   0.063568      0.751701
# 7       LogisticRegression  0.278402   0.066607      0.748299
# 8       LogisticRegression    0.2953   0.076272      0.782313
# 9       LogisticRegression  0.329357   0.061985      0.789116
# 10                     SVC  0.367457   0.198105      0.802721
# 11                     SVC  0.473383   0.244131      0.812925
# 12                     SVC  0.571932   0.246858       0.79932
# 13                     SVC  0.421775   0.238789      0.826531
# 14                     SVC  0.395364   0.231068      0.812925
# 15    KneighborsClassifier  0.170481   0.089538       0.62585
# 16    KneighborsClassifier  0.167391   0.084294       0.62585
# 17    KneighborsClassifier  0.209558   0.102682      0.605442
# 18    KneighborsClassifier  0.199537   0.080623      0.656463
# 19    KneighborsClassifier  0.183292   0.096884      0.564626
# 20  DecisionTreeClassifier  0.269689   0.064554      0.782313
# 21  DecisionTreeClassifier  0.334227   0.051885      0.782313
# 22  DecisionTreeClassifier  0.214173   0.060498      0.772109
# 23  DecisionTreeClassifier   0.25082   0.061558      0.785714
# 24  DecisionTreeClassifier  0.255534   0.060679      0.782313
# 25           XGBClassifier  1.123616   0.066474       0.85034
# 26           XGBClassifier  0.925531    0.06506      0.857143
# 27           XGBClassifier  0.827148   0.065591      0.860544
# 28           XGBClassifier  1.000309   0.069985      0.870748
# 29           XGBClassifier  1.061876     0.0656      0.853741
# 30          LGBMClassifier  1.945199   0.070574      0.846939
# 31          LGBMClassifier  1.838848   0.078622       0.85034
# 32          LGBMClassifier  1.918235   0.074754      0.863946
# 33          LGBMClassifier   1.80116   0.064633      0.877551
# 34          LGBMClassifier  2.006962   0.067991      0.860544
#
#    test_balanced_accuracy   test_f1 test_precision test_recall test_roc_auc  \
# 0                0.452236  0.206186       0.136986    0.416667     0.450457
# 1                0.474848  0.222222       0.148936      0.4375     0.464431
# 2                0.553967  0.288462       0.186335    0.638298     0.501809
# 3                0.484581  0.236967       0.152439    0.531915     0.472435
# 4                0.392368  0.154639       0.102041    0.319149     0.436902
# 5                0.721799  0.468085       0.354839      0.6875      0.81648
# 6                0.725864   0.47482       0.362637      0.6875     0.821054
# 7                0.729606  0.471429       0.354839    0.702128     0.835559
# 8                0.767077  0.522388       0.402299    0.744681     0.829012
# 9                0.771126  0.530303       0.411765    0.744681     0.796796
# 10               0.697663  0.472727       0.419355    0.541667     0.785654
# 11                0.70376  0.485981       0.440678    0.541667     0.765244
# 12               0.647989   0.40404       0.384615    0.425532       0.7688
# 13               0.715867  0.504854       0.464286    0.553191     0.808769
# 14               0.690542  0.466019       0.428571    0.510638     0.758033
# 15               0.633892  0.360465           0.25    0.645833     0.700965
# 16               0.650661     0.375       0.257812      0.6875     0.678862
# 17               0.661814  0.376344       0.251799    0.744681     0.711388
# 18               0.657722  0.380368       0.267241    0.659574     0.683651
# 19               0.585839  0.311828       0.208633    0.617021     0.631751
# 20               0.626778  0.372549       0.351852    0.395833     0.626778
# 21               0.651931  0.407407       0.366667    0.458333     0.651931
# 22                0.58011  0.294737       0.291667    0.297872      0.58011
# 23               0.665733  0.422018       0.370968    0.489362     0.665733
# 24               0.637867  0.384615       0.350877    0.425532     0.637867
# 25               0.650661  0.435897       0.566667    0.354167     0.782266
# 26               0.688262       0.5       0.583333      0.4375     0.801999
# 27                0.64997  0.438356       0.615385    0.340426     0.826686
# 28               0.638815  0.424242       0.736842    0.297872     0.816694
# 29               0.637307  0.410959       0.576923    0.319149     0.793953
# 30               0.623476  0.383562           0.56    0.291667     0.774221
# 31               0.667429  0.463415       0.558824    0.395833      0.78794
# 32               0.617538     0.375       0.705882    0.255319     0.819623
# 33               0.651477  0.454545       0.789474    0.319149     0.823671
# 34               0.667198  0.467532            0.6    0.382979     0.803342
#
#    test_average_precision time_seconds
# 0                0.151886     1.438098
# 1                0.154762     0.253079
# 2                0.160352     0.332812
# 3                0.153053     0.295469
# 4                0.147141      0.24909
# 5                0.555226     0.365899
# 6                0.590194     0.351703
# 7                0.635336     0.345009
# 8                0.598801     0.371572
# 9                0.566288     0.391341
# 10               0.510462     0.565562
# 11               0.510419     0.717513
# 12                0.42803      0.81879
# 13               0.553458     0.660564
# 14               0.556934     0.626431
# 15               0.301731     0.260019
# 16               0.259412     0.251684
# 17               0.305287      0.31224
# 18               0.257352     0.280161
# 19               0.238471     0.280176
# 20               0.237914     0.334243
# 21               0.256491     0.386113
# 22               0.199124     0.274671
# 23                0.26317     0.312378
# 24               0.241146     0.316212
# 25               0.527394      1.19009
# 26               0.559397     0.990591
# 27               0.578479     0.892739
# 28               0.599657     1.070295
# 29               0.538708     1.127476
# 30               0.494884     2.015773
# 31               0.543911      1.91747
# 32               0.531296     1.992989
# 33               0.589152     1.865793
# 34               0.561396     2.074953

# %%
#vou usar a métrica average_precision por combinar as métricas precisão e recall dando peso a ambas.
df_resultados.groupby("model").mean().sort_values("test_average_precision")
# Out:
#                         fit_time score_time test_accuracy  \
# model
# DummyClassifier         0.429101   0.084608      0.473469
# DecisionTreeClassifier  0.264889   0.059835      0.780952
# KneighborsClassifier    0.186052   0.090804      0.615646
# SVC                     0.445982    0.23179      0.810884
# LGBMClassifier          1.902081   0.071315      0.859864
# XGBClassifier           0.987696   0.066542      0.858503
# LogisticRegression      0.297895   0.067209      0.763265
#
#                        test_balanced_accuracy   test_f1 test_precision  \
# model
# DummyClassifier                        0.4716  0.221695       0.145348
# DecisionTreeClassifier               0.632484  0.376265       0.346406
# KneighborsClassifier                 0.637986  0.360801       0.247097
# SVC                                  0.691164  0.466725       0.427501
# LGBMClassifier                       0.645424  0.428811       0.642836
# XGBClassifier                        0.653003  0.441891        0.61583
# LogisticRegression                   0.743094  0.493405       0.377276
#
#                        test_recall test_roc_auc test_average_precision  \
# model
# DummyClassifier           0.468706     0.465207               0.153439
# DecisionTreeClassifier    0.413387     0.632484               0.239569
# KneighborsClassifier      0.670922     0.681323               0.272451
# SVC                       0.514539       0.7773               0.511861
# LGBMClassifier            0.328989     0.801759               0.544128
# XGBClassifier             0.349823      0.80432               0.560727
# LogisticRegression        0.713298      0.81978               0.589169
#
#                        time_seconds
# model
# DummyClassifier             0.51371
# DecisionTreeClassifier     0.324723
# KneighborsClassifier       0.276856
# SVC                        0.677772
# LGBMClassifier             1.973396
# XGBClassifier              1.054238
# LogisticRegression         0.365105

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# 3. Aplicação da Regressão Logística:
#
# Modelo treinado com n_clusters=5 e random_state=42 para reprodutibilidade
#
# Pipeline integrando pré-processamento e modelagem

# %%
#como eu vou testar todos os solvers, receberei diversos avisos, uma vez que apenas o saga é compatível como o ElasticNet
param_grid= {
    "clf__C":[0.1, 1, 10, 100],
    "clf__penalty": ['l1','l2', 'elasticnet', None],
    'clf__l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.9],
}

# %%
clf = LogisticRegression(random_state=RANDOM_STATE, solver='saga') #para base de dado grande, o saga é indicado
grid_search = grid_search_cv_classificador(
    clf, param_grid, kf, preprocessamento, refit_metric = "average_precision", 
)
grid_search
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('one_hot',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['Viagens '
#                                                                           'trab',
#                                                                           'Departamento',
#                                                                           'Área '
#                                                                           'form',
#                                                                           'Gênero',
#                                                                           'Cargo',
#                                                                           'Estado '
#                                                                           'civil',
#                                                                           'Hora '
#                                                                           'extra']),
#                                                                         ('ordinal',
#                                                                          OrdinalEncoder(),
#                                                                          ['Satisf '
#                                                                           'amb',
#                                                                           'Formação '
#                                                                           'acad',
#                                                                           'Satisf '
#                                                                           't...
#                                        ('sampler', SMOTETomek(random_state=42)),
#                                        ('clf',
#                                         LogisticRegression(random_state=42,
#                                                            solver='saga'))]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.1, 1, 10, 100],
#                          'clf__l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.9],
#                          'clf__penalty': ['l1', 'l2', 'elasticnet', None]},
#              refit='average_precision',
#              scoring=['accuracy', 'balanced_accuracy', 'f1', 'precision',
#                       'recall', 'roc_auc', 'average_precision'],
#              verbose=1)

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\linear_model\_logistic.py:1197: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('one_hot',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['Viagens '
#                                                                           'trab',
#                                                                           'Departamento',
#                                                                           'Área '
#                                                                           'form',
#                                                                           'Gênero',
#                                                                           'Cargo',
#                                                                           'Estado '
#                                                                           'civil',
#                                                                           'Hora '
#                                                                           'extra']),
#                                                                         ('ordinal',
#                                                                          OrdinalEncoder(),
#                                                                          ['Satisf '
#                                                                           'amb',
#                                                                           'Formação '
#                                                                           'acad',
#                                                                           'Satisf '
#                                                                           't...
#                                        ('sampler', SMOTETomek(random_state=42)),
#                                        ('clf',
#                                         LogisticRegression(random_state=42,
#                                                            solver='saga'))]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.1, 1, 10, 100],
#                          'clf__l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.9],
#                          'clf__penalty': ['l1', 'l2', 'elasticnet', None]},
#              refit='average_precision',
#              scoring=['accuracy', 'balanced_accuracy', 'f1', 'precision',
#                       'recall', 'roc_auc', 'average_precision'],
#              verbose=1)

# %%
grid_search.best_params_
#L1_ratio só faz sentido com Elastic Net
# Out:
# {'clf__C': 0.1, 'clf__l1_ratio': 0.1, 'clf__penalty': 'l1'}

# %%
grid_search.best_score_
# Out:
# 0.6134759469308106

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['Viagens trab',
#                                                    'Departamento', 'Área form',
#                                                    'Gênero', 'Cargo',
#                                                    'Estado civil',
#                                                    'Hora extra']),
#                                                  ('ordinal', OrdinalEncoder(),
#                                                   ['Satisf amb',
#                                                    'Formação acad',
#                                                    'Satisf trab', 'Envolv trab',
#                                                    'Nível cargo',
#                                                    'Avaliação desemp',
#                                                    'Satisf relac', 'Opc ações',
#                                                    'Equil vida-trab']),
#                                                  ('mi...
#                                                  ('power_transformer',
#                                                   PowerTransformer(),
#                                                   ['Sal diário',
#                                                    'Distância casa', 'Sal hora',
#                                                    'Renda mensal',
#                                                    'Taxa mensal',
#                                                    'Nº empresas trab',
#                                                    '% aumento sal',
#                                                    'Anos traba',
#                                                    'Treinam ultm ano',
#                                                    'Anos empresa',
#                                                    'Anos cargo atual',
#                                                    'Anos ult prom',
#                                                    'Anos gerente atual'])])),
#                 ('sampler', SMOTETomek(random_state=42)),
#                 ('clf',
#                  LogisticRegression(C=0.1, l1_ratio=0.1, penalty='l1',
#                                     random_state=42, solver='saga'))])

# %%
#avaliar oos resultados de outras métricas e o desvio padrão
colunas_teste= [coluna for coluna in df_resultados.columns if coluna.startswith('test')]
colunas_teste
# Out:
# ['test_accuracy',
#  'test_balanced_accuracy',
#  'test_f1',
#  'test_precision',
#  'test_recall',
#  'test_roc_auc',
#  'test_average_precision']

# %%
colunas_test_mean = ['mean_'+coluna for coluna in colunas_teste]
colunas_test_mean
# Out:
# ['mean_test_accuracy',
#  'mean_test_balanced_accuracy',
#  'mean_test_f1',
#  'mean_test_precision',
#  'mean_test_recall',
#  'mean_test_roc_auc',
#  'mean_test_average_precision']

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)

cv_results = cv_results[colunas_test_mean].iloc[grid_search.best_index_ , :]

cv_results.T
# Out:
# mean_test_accuracy             0.778231
# mean_test_balanced_accuracy    0.760540
# mean_test_f1                   0.516798
# mean_test_precision            0.398838
# mean_test_recall               0.734397
# mean_test_roc_auc              0.820381
# mean_test_average_precision    0.613476
# Name: 0, dtype: float64

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_['clf'].coef_[0],
    grid_search.best_estimator_['preprocessor'].get_feature_names_out() #o nome das features
)
coefs
# Out:
#                                             coeficiente
# power_transformer__Anos traba                 -0.540913
# ordinal__Envolv trab                          -0.401941
# ordinal__Satisf amb                           -0.382237
# ordinal__Satisf trab                          -0.329133
# one_hot__Estado civil_Divorciado              -0.313061
# power_transformer__Renda mensal               -0.307958
# ordinal__Opc ações                            -0.224045
# ordinal__Satisf relac                         -0.216830
# power_transformer__Anos cargo atual           -0.203925
# ordinal__Equil vida-trab                      -0.194898
# power_transformer__Anos gerente atual         -0.156103
# power_transformer__Treinam ultm ano           -0.154856
# power_transformer__% aumento sal              -0.143270
# power_transformer__Sal diário                 -0.102456
# standard__Idade                               -0.041756
# one_hot__Cargo_Diretor de produção             0.000000
# one_hot__Departamento_Recursos Humanos         0.000000
# power_transformer__Taxa mensal                 0.000000
# one_hot__Área form_Ciências médicas            0.000000
# one_hot__Cargo_Diretor de pesquisa             0.000000
# ordinal__Avaliação desemp                      0.000000
# ordinal__Nível cargo                           0.000000
# one_hot__Área form_Outros                      0.000000
# one_hot__Área form_Marketing                   0.000000
# ordinal__Formação acad                         0.000000
# one_hot__Cargo_Executivo de vendas             0.000000
# one_hot__Cargo_Gerente                         0.000000
# one_hot__Cargo_Recursos Humanos                0.000000
# one_hot__Cargo_Representante de saúde          0.000000
# one_hot__Área form_Recursos Humanos            0.000000
# one_hot__Cargo_Representante de vendas         0.000000
# power_transformer__Sal hora                    0.008275
# power_transformer__Anos empresa                0.110821
# power_transformer__Distância casa              0.346192
# one_hot__Gênero_Masculino                      0.347185
# one_hot__Área form_Formação técnica            0.381913
# power_transformer__Anos ult prom               0.391135
# one_hot__Viagens trab_Viaja_raramente          0.465675
# power_transformer__Nº empresas trab            0.475959
# one_hot__Cargo_Técnico de laboratório          0.476719
# one_hot__Estado civil_Solteiro                 0.736191
# one_hot__Departamento_Vendas                   0.755243
# one_hot__Viagens trab_Viaja_frequentemente     1.196748
# one_hot__Hora extra_Sim                        1.785086

# %%
coeficientes_pouca_relev = coefs.query("coeficiente == 0")
coeficientes_pouca_relev
# Out:
#                                         coeficiente
# one_hot__Cargo_Diretor de produção              0.0
# one_hot__Departamento_Recursos Humanos          0.0
# power_transformer__Taxa mensal                  0.0
# one_hot__Área form_Ciências médicas             0.0
# one_hot__Cargo_Diretor de pesquisa              0.0
# ordinal__Avaliação desemp                       0.0
# ordinal__Nível cargo                            0.0
# one_hot__Área form_Outros                       0.0
# one_hot__Área form_Marketing                    0.0
# ordinal__Formação acad                          0.0
# one_hot__Cargo_Executivo de vendas              0.0
# one_hot__Cargo_Gerente                          0.0
# one_hot__Cargo_Recursos Humanos                 0.0
# one_hot__Cargo_Representante de saúde           0.0
# one_hot__Área form_Recursos Humanos             0.0
# one_hot__Cargo_Representante de vendas          0.0

# %%
plot_coeficientes(coefs.query('coeficiente != 0'))

# %% [markdown]
# #Lembrar o Departamento de Pesquisa e Desenvolvimento tem mais pessoas e isso pode influenciar o resultado
# Os coeficientes hora extra, viagem a trabalho frequentemente, pessoas solteiras e pessoas com formação técnica são mais altos em relação ao attrition - transformar em odds para facilitar o entendimento

# %%
coefs_odds = coefs.copy()
coefs_odds["coeficiente"] = np.exp(coefs_odds["coeficiente"])

coefs_odds['coeficiente'].sort_values(ascending=False)
# Out:
# one_hot__Hora extra_Sim                       5.960092
# one_hot__Viagens trab_Viaja_frequentemente    3.309337
# one_hot__Departamento_Vendas                  2.128128
# one_hot__Estado civil_Solteiro                2.087966
# one_hot__Cargo_Técnico de laboratório         1.610781
# power_transformer__Nº empresas trab           1.609557
# one_hot__Viagens trab_Viaja_raramente         1.593090
# power_transformer__Anos ult prom              1.478657
# one_hot__Área form_Formação técnica           1.465085
# one_hot__Gênero_Masculino                     1.415078
# power_transformer__Distância casa             1.413674
# power_transformer__Anos empresa               1.117195
# power_transformer__Sal hora                   1.008309
# one_hot__Área form_Marketing                  1.000000
# one_hot__Cargo_Representante de vendas        1.000000
# one_hot__Área form_Recursos Humanos           1.000000
# one_hot__Cargo_Representante de saúde         1.000000
# one_hot__Cargo_Recursos Humanos               1.000000
# one_hot__Cargo_Gerente                        1.000000
# one_hot__Cargo_Executivo de vendas            1.000000
# ordinal__Formação acad                        1.000000
# one_hot__Área form_Outros                     1.000000
# ordinal__Nível cargo                          1.000000
# ordinal__Avaliação desemp                     1.000000
# one_hot__Cargo_Diretor de pesquisa            1.000000
# one_hot__Área form_Ciências médicas           1.000000
# power_transformer__Taxa mensal                1.000000
# one_hot__Departamento_Recursos Humanos        1.000000
# one_hot__Cargo_Diretor de produção            1.000000
# standard__Idade                               0.959104
# power_transformer__Sal diário                 0.902618
# power_transformer__% aumento sal              0.866520
# power_transformer__Treinam ultm ano           0.856538
# power_transformer__Anos gerente atual         0.855471
# ordinal__Equil vida-trab                      0.822918
# power_transformer__Anos cargo atual           0.815524
# ordinal__Satisf relac                         0.805067
# ordinal__Opc ações                            0.799279
# power_transformer__Renda mensal               0.734946
# one_hot__Estado civil_Divorciado              0.731205
# ordinal__Satisf trab                          0.719547
# ordinal__Satisf amb                           0.682333
# ordinal__Envolv trab                          0.669021
# power_transformer__Anos traba                 0.582217
# Name: coeficiente, dtype: float64

# %%
plot_coeficientes(coefs_odds.query("coeficiente != 1"))

# %% [markdown]
# Os funcionários que fazem hora extra com frequência tem 3.8 x mais chance de pedir demissão, seguido por quem viagem frequentemente( 2.11) e por quem é solteiro (1.83) em relação aos que não fazem.
# Os funcionários que  se sentem envolvidos com o trabalho, com a renda mensal alta e satisfação com o ambiente de trabalho possuem 0.6x menos chance de pedir demissão em relação aos demais

# %%
ConfusionMatrixDisplay.from_estimator(
    grid_search.best_estimator_,
    X,
    y,
    display_labels=le.classes_,

)
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ConfusionMatrixDisplay.from_estimator(
    grid_search.best_estimator_,
    X,
    y,
    display_labels=le.classes_,
    normalize='true',

)
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
joblib.dump(grid_search, MODELO)
# Out:
# ['D:\\ciencias_dados\\python_pratica\\hashtag\\ciencias_dados\\machine_learning\\projeto_ibm\\modelos\\modelo.pkl']

# %% [markdown]
# ## Conclusão
#
# O modelo identificou 5 clusters com perfis distintos:
#
# Cluster 2 (19.5%): Alto potencial (alta renda + alto gasto) → Priorizar campanhas premium.
#
# Cluster 4 (26.5%): Renda e gastos moderados + idade alta → Oferecer produtos de valor intermediário.
#
# Cluster 1 (10%): Baixa renda e gastos → Evitar investimentos pesados.
#
# Validação:
#
# Diferenças por gênero foram observadas (ex.: Cluster 0 com 60% mulheres).
#
# Aplicação:
#
# Essa segmentação permite personalizar estratégias de marketing e otimizar alocação de recursos.
#
# Plano de ação
#
# Avaliar os motivos que levam os funcionários a fazerem hora extra.
#     Mão de obra insuficiente
#     Falta de organização institucional
#     Falta de treinamento
#     Necessidade de investimento em tecnologia
# Possibilidade de diminuir as viagens de negócios.
#     Como isso afeta a equipe de vendas?
# Como a renda mensal de cada setor e nível da empresa se compara com o mercado?
# Ações voltadas para o clima organizacional
