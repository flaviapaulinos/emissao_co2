# %% [markdown]
# ## Construção do modelo de classificação:
#
# Comparar e implementar um modelo preditivo de classificação.

# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    LabelEncoder, 
    MinMaxScaler, 
    OrdinalEncoder,
    OneHotEncoder, 
    PowerTransformer,
    QuantileTransformer,
)

# classificador referência
from sklearn.dummy import DummyClassifier

# estudo lineares
from sklearn.linear_model import Lasso, LinearRegression, Ridge

#estudo knn
from sklearn.neighbors import KNeighborsRegressor

# estudo árvores
from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# estudo SVM
from sklearn.svm import LinearSVR

# exportar o modelo
from joblib import dump, load

from src.auxiliares import dataframe_coeficientes
from src.config import DADOS_TRATADOS,  MODELO_FINAL
from src.graficos import plot_comparar_metricas_modelos, plot_coeficientes, plot_residuos_estimador
from src.models import RANDOM_STATE
from src.models import (
    grid_search_cv_regressor,
    treinar_e_validar_modelo_regressao,
    organiza_resultados,
)

#pandas configurando para mostrar todas as linhas e colunas
pd.set_option ('display.max_columns', None)
#configurando pandas para não mostrar notação científica
pd.set_option('display.float_format', lambda x: '%.2f' % x)


sns.set_theme(palette='viridis')

# %%
df = pd.read_parquet(DADOS_TRATADOS)

df.head()
# Out:
#    model_year transmission         fuel_type  city_l_100_km  highway_l_100_km  \
# 0        2005            A      reg_gasoline           9.20              7.20
# 1        2005            M      reg_gasoline           9.10              7.30
# 2        2005            A  premium_gasoline          15.90             11.10
# 3        2005           AS  premium_gasoline          15.10             10.50
# 4        2005            M  premium_gasoline          15.10             10.50
#
#    combined_l_100_km  co2_emissions_g_km engine_size_l vehicle_class cylinders
# 0               8.30                 191     up_to_1.9           car   up_to_4
# 1               8.30                 191     up_to_1.9           car   up_to_4
# 2              13.70                 315       up_to_5           suv   up_to_6
# 3              13.00                 299       up_to_3           car   up_to_6
# 4              13.00                 299       up_to_5           car   up_to_6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20520 entries, 0 to 20519
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_year          20520 non-null  int64
#  1   transmission        20520 non-null  object
#  2   fuel_type           20520 non-null  object
#  3   city_l_100_km       20520 non-null  float64
#  4   highway_l_100_km    20520 non-null  float64
#  5   combined_l_100_km   20520 non-null  float64
#  6   co2_emissions_g_km  20520 non-null  int64
#  7   engine_size_l       20520 non-null  category
#  8   vehicle_class       20520 non-null  object
#  9   cylinders           20520 non-null  category
# dtypes: category(2), float64(3), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
# Agrupamento das colunas de acordo com o pré-processamento necessário
colunas_categoricas_nao_ordenadas = [
    'vehicle_class',
    'transmission',
    'fuel_type',
]
colunas_categoricas_ordenadas = [
    'engine_size_l',
    'cylinders',
     
]
coluna_target= ['co2_emissions_g_km']

#model_year tem uma distribuição bem próxima do normal - mim_max
coluna_min_max=['model_year']

#as demais colunas numéricas apesar de próximas do normal 
#mas possuem uma certa assimetria - power_transformer
colunas_power_transform = [coluna for coluna in df.columns if coluna not in (
    colunas_categoricas_nao_ordenadas+colunas_categoricas_ordenadas+coluna_target+ coluna_min_max)]

# %%
X= df.drop(columns=coluna_target)
y= df[coluna_target]

# %% [markdown]
# ##### ESTRATÉGIA DE PRÉ-PROCESSAMENTO:
#
# 1. Variáveis categóricas não ordenadas: One-Hot Encoding
#    (para classes sem relação ordinal)
# 2. Variáveis categóricas ordenadas: Ordinal Encoding
#    (para classes com relação ordinal explícita)
# 3. Variáveis numéricas:
#    - Normalização Min-Max para 'model_year' (distribuição quase normal)
#    - Power Transform para outras numéricas (assimetria presente)
#
# ##### DIFERENCIAÇÃO DE PRÉ-PROCESSAMENTO:
#
# 1. Para modelos lineares/SVM/KNN: Normalização mais robusta
#    - OneHotEncoding para categóricas
#    - PowerTransformer para numéricas assimétricas
# 2. Para modelos baseados em árvores: Menos pré-processamento necessário
#    - Apenas codificação ordinal/one-hot
#    - Não requer normalização de features numéricas

# %%
# Preprocessamento
preprocessamento = ColumnTransformer(
    transformers=[
        ('one_hot', OneHotEncoder(drop='first'), colunas_categoricas_nao_ordenadas),
        ('ordinal', OrdinalEncoder(categories='auto'),colunas_categoricas_ordenadas),
        ('min_max', MinMaxScaler(), coluna_min_max),
        ('power_transformer', PowerTransformer(), colunas_power_transform)
    ]
)

preprocessamento_arvore = ColumnTransformer(
    transformers=[
        ('one_hot', OneHotEncoder(drop='first'), colunas_categoricas_nao_ordenadas),
        ('ordinal', OrdinalEncoder(categories='auto'),colunas_categoricas_ordenadas),
    ]
)

# %% [markdown]
# ###### ESTRATÉGIA DE MODELAGEM:
#
# 1. Testar diversos tipos de algoritmos:
#    - Lineares (simples, interpretáveis)
#    - Baseados em árvores (potentes para relações não-lineares)
#    - SVM (para comparação)
# 2. Usar validação cruzada para avaliação robusta
# 3. Avaliar o melhor modelo para tunagem de hiperparâmetros

# %%
regressores = {
    "DummyClassifier": {
        "preprocessor": None,
        "regressor": DummyClassifier(strategy="stratified"),
        "target_transformer":None,
    },
    
     "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution='normal')
    },

    "Lasso": {
        "preprocessor": preprocessamento,
        "regressor": Lasso(),
        "target_transformer": QuantileTransformer(output_distribution='normal')
    },


    "Ridge": {
        "preprocessor": preprocessamento,
        "regressor": Ridge(),
        "target_transformer": QuantileTransformer(output_distribution='normal')
    },

   #SVM  
    "LinearSVR": {
        "preprocessor": preprocessamento,
        "regressor": LinearSVR(max_iter=5000),
        "target_transformer": QuantileTransformer(output_distribution='normal')
    },
    #knn
    "KneighborsRegressor":{
        "preprocessor": preprocessamento,
        "regressor": KNeighborsRegressor(n_jobs=-1),
        "target_transformer": QuantileTransformer(output_distribution='normal')
    },
  
    # modelos baseado em árvores de decisão (dispensam target_transformer)
    "DecisionTreeRegressor": {
        "preprocessor": preprocessamento_arvore,
        "regressor": DecisionTreeRegressor(random_state=RANDOM_STATE),
        "target_transformer":None,
    },
    
    "XGBRegressor": {
        "preprocessor": preprocessamento_arvore,
        "regressor": XGBRegressor(
            random_state=RANDOM_STATE,
            n_jobs=-1,
        ),
        "target_transformer":None,
     },

    "LGBMRegressor": {
        "preprocessor": preprocessamento_arvore,
        "regressor": LGBMRegressor(
            random_state=RANDOM_STATE,
            n_jobs=-1,
            verbose=-1,
        ),
         "target_transformer":None,
    }, 
   
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressores.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\ProgramFiles\anaconda\env\machine_learning\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
#vou usar a métrica average_precision por combinar as métricas precisão e recall dando peso a ambas.
df_resultados.groupby("model").mean().sort_values("test_neg_root_mean_squared_error")
# Out:
#                       fit_time score_time test_r2  \
# model
# DummyClassifier           0.01       0.07   -1.02
# Lasso                     0.21       0.04   -0.01
# LGBMRegressor             1.22       0.05    0.82
# XGBRegressor              0.61       0.05    0.82
# DecisionTreeRegressor     0.13       0.03    0.82
# KneighborsRegressor       0.19       0.59    1.00
# LinearSVR                 4.40       0.04    1.00
# Ridge                     0.20       0.04    1.00
# LinearRegression          0.24       0.04    1.00
#
#                       test_neg_mean_absolute_error  \
# model
# DummyClassifier                             -70.94
# Lasso                                       -49.84
# LGBMRegressor                               -19.99
# XGBRegressor                                -19.82
# DecisionTreeRegressor                       -19.80
# KneighborsRegressor                          -2.11
# LinearSVR                                    -2.24
# ...

# %% [markdown]
# o modelo ridge não chega a zerar nenhum coeficiente (diferente do Lasso), e permite visualizar de forma clara a importância dos coeficientes para o target

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# ##### OBSERVAÇÕES INICIAIS:
#
# 1. Modelos lineares (Ridge, LinearRegression) apresentam excelente desempenho (R² ~1.0)
# 2. Lasso teve desempenho ruim - possivelmente alpha padrão muito alto
# 3. Modelos baseados em árvores têm desempenho similar entre si (R² ~0.82)
# 4. KNN também apresentou excelente desempenho
# """
#
# ###### --- OTIMIZAÇÃO DO MODELO RIDGE ---
#
#
# JUSTIFICATIVA PARA ESCOLHA DO RIDGE:
#
# 1. Excelente desempenho (melhor RMSE entre os lineares)
# 2. Permite interpretação dos coeficientes
# 3. Mais estável que LinearRegression puro
# 4. Menor tempo de execução que SVM/KNN

# %%
param_grid = {
    'regressor__reg__alpha': [0.1, 0.25, 0.5, 0,75 1.0, 2.0, 4.0, 6.0],
    
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution='normal'),
    param_grid=param_grid,
)
grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['vehicle_class',
#                                                                                                                'transmission',
#                                                                                                                'fuel_type']),
#                                                                                                              ('ordinal',
# ...

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['vehicle_class',
#                                                                                                                'transmission',
#                                                                                                                'fuel_type']),
#                                                                                                              ('ordinal',
# ...

# %%
grid_search.best_params_
# Out:
# {'regressor__reg__alpha': 0.5}

# %%
grid_search.best_score_
# Out:
# -3.753773382193999

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(transformers=[('one_hot',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['vehicle_class',
#                                                                                         'transmission',
#                                                                                         'fuel_type']),
#                                                                                       ('ordinal',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['engine_size_l',
# ...

# %%
#análise coeficientes
coefs=dataframe_coeficientes(
    grid_search.best_estimator_.regressor_['reg'].coef_,
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)
coefs
# Out:
#                                         coeficiente
# one_hot__fuel_type_ethanol                    -2.15
# one_hot__fuel_type_premium_gasoline           -0.62
# one_hot__fuel_type_reg_gasoline               -0.61
# power_transformer__combined_l_100_km          -0.06
# one_hot__vehicle_class_special_purpose        -0.03
# one_hot__vehicle_class_suv                    -0.02
# ordinal__engine_size_l                        -0.02
# one_hot__vehicle_class_pickup_truck           -0.01
# one_hot__vehicle_class_station_wagon          -0.01
# one_hot__transmission_M                       -0.01
# ordinal__cylinders                            -0.00
# one_hot__transmission_AS                       0.00
# one_hot__vehicle_class_van                     0.01
# one_hot__transmission_AM                       0.03
# one_hot__transmission_AV                       0.05
# min_max__model_year                            0.11
# power_transformer__highway_l_100_km            0.43
# ...

# %%
##plot_coeficientes(coefs)

# %% [markdown]
# * os coeficientes mais relevantes para o modelo são: consumo em cidade e em estrada, ano do modelo.
#
# * a análise de coeficientes para modelos categóricos precisa ser comparado a variável de referência (que foi dropada), considerando todas as outras fetaures inalteradas.
#
# * O impacto inversamente proporcional do etanol (responsável por menor emissão de C02)  remete ao EDA, quando foi constatado seu uso por veículos mais pesados.

# %%
plot_residuos_estimador(grid_search.best_estimator_, X,y, fracao_amostra=0.1, eng_formatter=True)

# %%
dump(grid_search.best_estimator_, MODELO_FINAL)
# Out:
# ['D:\\ciencias_dados\\python_pratica\\hashtag\\ciencias_dados\\machine_learning\\projeto_consumo_combustivel_canada - Copia\\modelos\\ridge.joblib']

# %% [markdown]
# ## Conclusão:
#
# 1. Principais drivers positivos:
#    - Consumo na cidade (city_l_100_km)
#    - Consumo na estrada (highway_l_100_km)
#    - Ano do modelo (model_year)
#    -
# 2. Principais drivers negativos:
#    - Uso de etanol (fuel_type_ethanol)
#    - Gasolina premium/regular
#
# 3. Insights:
#    - Etanol mostra impacto negativo nas emissões (confirmando EDA)
#    - Veículos mais novos tendem a emitir mais (possivelmente por serem maiores/mais potentes)
#    - Pesquisar se a razão da redução de veículos está associada ao investimento de transporte público, carros elétricos ou a um cenário econômico e avaliar se é uma tendência e seu im,pacto na redução de emissão CO2.
